# %%
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(layout='wide')
 
df = pd.read_excel('SSW.xlsx', decimal=',')
df
# Out:
#     Serie/Numero CTRC  Serie/Numero CT-e   Tipo do Documento Praca Expedidora  \
# 0         BES000785-4                  0  SUBC REC FORM LISO             BELP
# 1         BES000787-1                  0  SUBC REC FORM LISO             BELP
# 2         BNS000198-8                  0  SUBC REC FORM LISO             BNUP
# 3         BNS000199-6                  0  SUBC REC FORM LISO             BNUP
# 4         BNS000200-3                  0  SUBC REC FORM LISO             BNUP
# ..                ...                ...                 ...              ...
# 749       PCB006238-3         7000006877       CARGA FECHADA             PCBP
# 750       PCB006239-1         7000006878       CARGA FECHADA             PCBP
# 751       PCB006240-5         7000006879              NORMAL             PCBP
# 752       PCS000042-6                  0  SUBC REC FORM LISO             PCBP
# 753       PGD000334-4         7000000297             REVERSA             PGDR
#
# ...
